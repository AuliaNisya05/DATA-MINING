# %%
import pandas as pd
import numpy as np

#object creation
s = pd.Series([1,3,5,np.nan,6,8])
dates = pd.date_range('2023-10-01', periods=6)
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))

print("Object Creation:")
print("Series:")
print(s)
print("\nDataFrame:")
print(df)
print("="*50)
# Out:
# Object Creation:
# Series:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64
#
# DataFrame:
#                    A         B         C         D
# 2023-10-01  0.598820 -0.861011 -1.140011 -0.250884
# 2023-10-02  0.317766 -0.619352  0.535284 -1.514186
# 2023-10-03  1.169132  0.924363 -1.757958 -1.041707
# 2023-10-04  0.708116 -0.213919 -1.209162  1.454382
# 2023-10-05 -0.247911  0.341415 -0.736442 -0.269141
# 2023-10-06 -1.317724 -0.802452  1.721470  0.872584
# ==================================================

# %%
#viewing data
print("Viewing Data:")
print("First 3 rows:")
print(df.head(3))
print("\nLast 2 row:")
print(df.tail(2))
print("\nIndex and Columns:")
print(df.index)
print(df.columns)
print("="*40)
# Out:
# Viewing Data:
# First 3 rows:
#                    A         B         C         D
# 2023-10-01 -0.626348  1.678760 -0.052759 -0.570817
# 2023-10-02 -0.129952  0.476785  0.618959  1.623883
# 2023-10-03 -0.966245 -0.764634 -0.971762 -0.941629
#
# Last 2 row:
#                    A         B         C         D
# 2023-10-05 -1.672322 -1.360159 -0.766169 -1.300240
# 2023-10-06 -0.936591 -2.744842 -0.527817 -1.839326
#
# Index and Columns:
# DatetimeIndex(['2023-10-01', '2023-10-02', '2023-10-03', '2023-10-04',
#                '2023-10-05', '2023-10-06'],
#               dtype='datetime64[ns]', freq='D')
# Index(['A', 'B', 'C', 'D'], dtype='object')
# ========================================

# %%
#Selection
print("Selection:")
print("Selecting a column (A):")
print(df['A'])
print("\nSelecting via by label (row 0):")
print(df.loc[dates[0]])
print("\nSelecting by position (row 1):")
print(df.iloc[1])
print("\nSelecting a subset of rows and columns:")
print(df.loc[dates[1:3], ['A', 'B']])
print("="*40)
# Out:
# Selection:
# Selecting a column (A):
# 2023-10-01    0.598820
# 2023-10-02    0.317766
# 2023-10-03    1.169132
# 2023-10-04    0.708116
# 2023-10-05   -0.247911
# 2023-10-06   -1.317724
# Freq: D, Name: A, dtype: float64
#
# Selecting via by label (row 0):
# A    0.598820
# B   -0.861011
# C   -1.140011
# D   -0.250884
# Name: 2023-10-01 00:00:00, dtype: float64
#
# Selecting by position (row 1):
# A    0.317766
# B   -0.619352
# C    0.535284
# D   -1.514186
# Name: 2023-10-02 00:00:00, dtype: float64
#
# Selecting a subset of rows and columns:
#                    A         B
# 2023-10-02  0.317766 -0.619352
# 2023-10-03  1.169132  0.924363
# ========================================

# %%
# Missing Data
df1 = df.reindex(index=dates[0:4], columns=list(df.columns) + ['E'])
df1.loc[dates[0]:dates[1], 'E'] = 1

print("Missing Data:")
print("DataFrame with missing values:")
print(df1)
print("\nDropping rows with missing values:")
print(df1.dropna())
print("\nFilling missing values:")
print(df1.fillna(value=0))
print("="*60)
# Out:
# Missing Data:
# DataFrame with missing values:
#                    A         B         C         D    E
# 2023-10-01  0.598820 -0.861011 -1.140011 -0.250884  1.0
# 2023-10-02  0.317766 -0.619352  0.535284 -1.514186  1.0
# 2023-10-03  1.169132  0.924363 -1.757958 -1.041707  NaN
# 2023-10-04  0.708116 -0.213919 -1.209162  1.454382  NaN
#
# Dropping rows with missing values:
#                    A         B         C         D    E
# 2023-10-01  0.598820 -0.861011 -1.140011 -0.250884  1.0
# 2023-10-02  0.317766 -0.619352  0.535284 -1.514186  1.0
#
# Filling missing values:
#                    A         B         C         D    E
# 2023-10-01  0.598820 -0.861011 -1.140011 -0.250884  1.0
# 2023-10-02  0.317766 -0.619352  0.535284 -1.514186  1.0
# 2023-10-03  1.169132  0.924363 -1.757958 -1.041707  0.0
# 2023-10-04  0.708116 -0.213919 -1.209162  1.454382  0.0
# ============================================================

# %%
# Operations
# a) Oprasi statistik menghitung rata-rata

print("Operations:")
print("Mean og each column:")
print(df.mean())
print("\nSum of each row:")
print(df.sum(axis=1))
print("="*40)
# Out:
# Operations:
# Mean og each column:
# A    0.204700
# B   -0.205159
# C   -0.431136
# D   -0.124825
# dtype: float64
#
# Sum of each row:
# 2023-10-01   -1.653086
# 2023-10-02   -1.280488
# 2023-10-03   -0.706170
# 2023-10-04    0.739418
# 2023-10-05   -0.912080
# 2023-10-06    0.473878
# Freq: D, dtype: float64
# ========================================

# %%
# b) Menggabungkan gua DataFrame
#Merge

left = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'], 'A': ['A0', 'A1', 'A2', 'A3'], 'B': ['B0','B1', 'B2', 'B3']})

right = pd.DataFrame({'key': ['K0', 'K1', 'K2', 'K3'], 'C': ['C0', 'C1', 'C2', 'C3'], 'D': ['D0', 'D1', 'D2', 'D3']})
merged_df = pd.merge(left, right, on='key')

print("Merge:")
print("Merged DataFrame:")
print(merged_df)
print("="*40)
# Out:
# Merge:
# Merged DataFrame:
#   key   A   B   C   D
# 0  K0  A0  B0  C0  D0
# 1  K1  A1  B1  C1  D1
# 2  K2  A2  B2  C2  D2
# 3  K3  A3  B3  C3  D3
# ========================================

# %%
# C) Mengelompokan data dan oprasi agregasi
# Grouping

grouped = df.groupby('A').sum()
print("Grouping:")
print("Grouped DataFrame:")
print(grouped)
print("="*40)
# Out:
# Grouping:
# Grouped DataFrame:
#                   B         C         D
# A
# -1.317724 -0.802452  1.721470  0.872584
# -0.247911  0.341415 -0.736442 -0.269141
#  0.317766 -0.619352  0.535284 -1.514186
#  0.598820 -0.861011 -1.140011 -0.250884
#  0.708116 -0.213919 -1.209162  1.454382
#  1.169132  0.924363 -1.757958 -1.041707
# ========================================

# %%
# d) Menggunakan fungsi tumpukan (stack)
# reshaping

stacked = df.stack()
unstacked = stacked.unstack()

print("Reshaping:")
print("Stacked DataFrame:")
print(stacked)
print("\nUnstacked DataFrame:")
print(unstacked)
print("="*40)
# Out:
# Reshaping:
# Stacked DataFrame:
# 2023-10-01  A    0.598820
#             B   -0.861011
#             C   -1.140011
#             D   -0.250884
# 2023-10-02  A    0.317766
#             B   -0.619352
#             C    0.535284
#             D   -1.514186
# 2023-10-03  A    1.169132
#             B    0.924363
#             C   -1.757958
#             D   -1.041707
# 2023-10-04  A    0.708116
#             B   -0.213919
#             C   -1.209162
#             D    1.454382
# 2023-10-05  A   -0.247911
#             B    0.341415
#             C   -0.736442
#             D   -0.269141
# 2023-10-06  A   -1.317724
#             B   -0.802452
#             C    1.721470
#             D    0.872584
# dtype: float64
#
# Unstacked DataFrame:
#                    A         B         C         D
# 2023-10-01  0.598820 -0.861011 -1.140011 -0.250884
# 2023-10-02  0.317766 -0.619352  0.535284 -1.514186
# 2023-10-03  1.169132  0.924363 -1.757958 -1.041707
# 2023-10-04  0.708116 -0.213919 -1.209162  1.454382
# 2023-10-05 -0.247911  0.341415 -0.736442 -0.269141
# 2023-10-06 -1.317724 -0.802452  1.721470  0.872584
# ========================================

# %%
# Time Series

ts = pd.Series(np.random.randn(1000), index=pd.date_range('2023-01-01', periods=1000))
cumulative_sum = ts.cumsum()

print("Time Series:")
print(ts.head())
print("\nCumulative Sum:")
print(cumulative_sum.head)
print("="*40)
# Out:
# Time Series:
# 2023-01-01   -0.387854
# 2023-01-02   -1.973749
# 2023-01-03    1.861372
# 2023-01-04   -0.365426
# 2023-01-05   -0.344403
# Freq: D, dtype: float64
#
# Cumulative Sum:
# <bound method NDFrame.head of 2023-01-01    -0.387854
# 2023-01-02    -2.361602
# 2023-01-03    -0.500230
# 2023-01-04    -0.865656
# 2023-01-05    -1.210059
#                 ...
# 2025-09-22   -39.993109
# 2025-09-23   -40.024370
# 2025-09-24   -40.743882
# 2025-09-25   -40.318812
# 2025-09-26   -40.406872
# Freq: D, Length: 1000, dtype: float64>
# ========================================

# %%
# Categoricals
import pandas as pd

# create a categorical Series
s = pd.Series(["cat", "dog", "bird", "cat", "dog"], dtype="category")

# Define new categories
new_categories = ["Category 1", "Category 2", "Category 3"]

# Create a new categorical Series with the new categories
s_new = s.cat.set_categories(new_categories)

print("Categoricals:")
print("Original Categorical Series:")
print(s)
print("\nNew Categorical Series with update categories:")
print(s_new)
# Out:
# Categoricals:
# Original Categorical Series:
# 0     cat
# 1     dog
# 2    bird
# 3     cat
# 4     dog
# dtype: category
# Categories (3, object): ['bird', 'cat', 'dog']
#
# New Categorical Series with update categories:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    NaN
# dtype: category
# Categories (3, object): ['Category 1', 'Category 2', 'Category 3']

# %%
import matplotlib.pyplot as plt
# Plotting
df.plot()
plt.show()

print("Plotting:")
print("="*40)
# Out:
# Plotting:
# ========================================

# %%
# Importing and Exporting Data
imported_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/sample_data.csv')

print("Importing and Exporting Data:")
print("Exported DataFrame to CSV:")
print(df)
print("\nImported DataFrame from CSV:")
print(imported_df)
print("="*40)
df.to_csv('sampel_data2.csv')
# Out:
# Importing and Exporting Data:
# Exported DataFrame to CSV:
#                    A         B         C         D
# 2023-10-01  0.598820 -0.861011 -1.140011 -0.250884
# 2023-10-02  0.317766 -0.619352  0.535284 -1.514186
# 2023-10-03  1.169132  0.924363 -1.757958 -1.041707
# 2023-10-04  0.708116 -0.213919 -1.209162  1.454382
# 2023-10-05 -0.247911  0.341415 -0.736442 -0.269141
# 2023-10-06 -1.317724 -0.802452  1.721470  0.872584
#
# Imported DataFrame from CSV:
#     SUBJECT Stim1 Stim2  Response
# 0         1     B     D         5
# 1         1     A     B         1
# 2         1     B     C         7
# 3         2     A     C         3
# 4         2     A     B         2
# 5         2     B     C         6
# 6         3     B     C         6
# 7         3     C     D         5
# 8         3     A     B         3
# 9         4     B     D         2
# 10        4     A     D         2
# 11        4     B     C         5
# 12        5     C     D         6
# 13        5     A     D         1
# 14        5     A     B         2
# 15        6     A     B         2
# 16        6     A     D         2
# 17        6     B     D         3
# 18        7     A     D         1
# 19        7     B     D         5
# 20        7     A     B         1
# 21        8     C     D         5
# 22        8     A     C         4
# 23        8     A     B         3
# 24        9     A     D         2
# 25        9     A     B         1
# 26        9     C     D         5
# 27       10     A     C         5
# 28       10     B     C         7
# 29       10     A     B         2
# ========================================
